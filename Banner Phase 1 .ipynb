# %%
import requests

# %%
import json

# %%
import pandas as pd

# %%
import numpy as np

# %%
import time

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'c2d178abd2b6b87a1c24e21c38bd5e24'

# %%
api_key = 'c2d178abd2b6b87a1c24e21c38bd5e24'

# %%
movie = tmdb.Movies(603)
response = movie.info()
movie.title
# Out:
# 'The Matrix'

# %%
movie.budget
# Out:
# 63000000

# %%
movie.popularity
# Out:
# 51.001

# %%
movie.revenue
# Out:
# 463517383

# %%
movie.vote_average
# Out:
# 8.1

# %%
identity = tmdb.Movies(2501)
response = identity.info()
identity.budget, identity.runtime
# Out:
# (60000000, 119)

# %%
movie_5 = tmdb.Movies(5).info()
movie_5
# Out:
# {'adult': False,
#  'backdrop_path': '/5J9lhMZHVQRfH8BV4hyehwptzKp.jpg',
#  'belongs_to_collection': None,
#  'budget': 4000000,
#  'genres': [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}],
#  'homepage': '',
#  'id': 5,
#  'imdb_id': 'tt0113101',
#  'original_language': 'en',
#  'original_title': 'Four Rooms',
#  'overview': "It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another.",
#  'popularity': 10.388,
#  'poster_path': '/uZSmxBLIuZ8gpadjAWNdA5aQDAc.jpg',
#  'production_companies': [{'id': 14,
#    'logo_path': '/m6AHu84oZQxvq7n1rsvMNJIAsMu.png',
#    'name': 'Miramax',
#    'origin_country': 'US'},
#   {'id': 59,
#    'logo_path': '/yH7OMeSxhfP0AVM6iT0rsF3F4ZC.png',
#    'name': 'A Band Apart',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
# ...

# %%
discover = tmdb.Discover()
response = discover.movie(year=2016)
response
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 257.988,
#    'vote_count': 725,
#    'video': False,
#    'poster_path': '/bAQ8O5Uw6FedtlCbJTutenzPVKd.jpg',
#    'id': 317442,
#    'adult': False,
#    'backdrop_path': '/l8ubUlfzlB5R2j9cJ3CN7tj0gmd.jpg',
#    'original_language': 'ja',
#    'original_title': 'The Last: Naruto the Movie',
#    'genre_ids': [28, 16, 10749],
#    'title': 'The Last: Naruto the Movie',
#    'vote_average': 7.9,
# ...

# %%
r5 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2017&sort_by=revenue.desc')

# %%
highest_revenue = r5.json()

highest_revenue_films = highest_revenue['results']
highest_revenue_films
# Out:
# [{'popularity': 48.844,
#   'vote_count': 11133,
#   'video': False,
#   'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg',
#   'id': 181808,
#   'adult': False,
#   'backdrop_path': '/5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg',
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Last Jedi',
#   'genre_ids': [28, 12, 878],
#   'title': 'Star Wars: The Last Jedi',
#   'vote_average': 6.9,
#   'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#   'release_date': '2017-12-13'},
#  {'popularity': 52.248,
#   'id': 321612,
#   'video': False,
#   'vote_count': 12866,
#   'vote_average': 7,
#   'title': 'Beauty and the Beast',
#   'release_date': '2017-03-16',
#   'original_language': 'en',
#   'original_title': 'Beauty and the Beast',
#   'genre_ids': [10751, 14, 10749],
# ...

# %%
# define column names for our new dataframe


# create dataframe with film and revenue columns
df = pd.DataFrame(columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-285f1060fa08> in <module>()
#       3
#       4 # create dataframe with film and revenue columns
# ----> 5 df = pd.DataFrame(columns=columns)
#
# NameError: name 'columns' is not defined

# %%
# for each of the highest revenue films make an api call for that specific movie to return the budget and revenue
for film in highest_revenue_films:
    columns = ['film', 'revenue', 'release_date']
    # print(film['title'])
    film = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film = film.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df.loc[len(df)]=[film['title'],film['revenue'], film['release_date']] # store title and revenue in our dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8c625227ba2f> in <module>()
#       6     film = film.json()
#       7     #print(locale.currency(film_revenue['revenue'], grouping=True ))
# ----> 8     df.loc[len(df)]=[film['title'],film['revenue'], film['release_date']] # store title and revenue in our dataframe
#
# NameError: name 'df' is not defined

# %%
df

# %%
r6 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&sort_by=revenue.desc')
r6.json()
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 1.987,
#    'id': 751181,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'El Khetta El Aayma',
#    'release_date': '2020-10-06',
#    'original_language': 'ar',
#    'original_title': 'الخطة العايمة',
#    'genre_ids': [35],
#    'backdrop_path': '/45gi04xjOxBu8s13aiqrXMrL4xw.jpg',
#    'adult': False,
#    'overview': 'As a man enlists the help of two people in order to steal important documents from a safe in a bank, they train two clueless thieves to do the job.',
#    'poster_path': '/bQGF1J3A0riXwdwrCQBVQB5zYvY.jpg'},
#   {'popularity': 1.526,
#    'id': 726254,
#    'video': False,
#    'vote_count': 1,
#    'vote_average': 10,
#    'title': 'Bruno Berti Sarrador Profissional',
#    'release_date': '',
#    'original_language': 'pt',
#    'original_title': 'Bruno Berti Sarrador Profissional',
#    'genre_ids': [36],
#    'backdrop_path': None,
# ...

# %%
r6.json().keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
r6.json()['page']
# Out:
# 1

# %%
r6.json()['total_results']
# Out:
# 10000

# %%
r6.json()['total_pages']
# Out:
# 500

# %%
len(r6.json()['results'])
# Out:
# 20

# %%
highest_revenue_ever = r6.json()

# %%
highest_revenue_films_ever = highest_revenue_ever['results']

# %%
columns = ['film', 'revenue', 'budget', 'release_date']
highest_revenue_ever_df = pd.DataFrame(columns=columns)

# %%
for film in highest_revenue_films_ever:
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id'])
                                +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    if film_revenue['budget'] > 281:
        # add film title, revenue, budget and release date to the dataframe
        highest_revenue_ever_df.loc[len(highest_revenue_ever_df)]=[film['title'],
        film_revenue['revenue'], (film_revenue['budget'] * -1), film_revenue['release_date']]

# %%
highest_revenue_ever_df
# Out:
#                                             film      revenue          budget  \
# 0                             El Khetta El Aayma  10000000000  -1000000000000
# 1              Bruno Berti Sarrador Profissional   7000000000     -1000000000
# 2                                        Russia!   3388844485        -2000000
# 3                              Avengers: Endgame   2797800564      -356000000
# 4                                         Avatar   2787965087      -237000000
# 5                                        Titanic   2187463944      -200000000
# 6                   Star Wars: The Force Awakens   2068223624      -245000000
# 7                         Avengers: Infinity War   2046239637      -300000000
# 8                               Nutra: the Movie   2000000000     -1000000000
# 9                                 Jurassic World   1671713208      -150000000
# 10                                 The Lion King   1656943394      -260000000
# ...

# %%
r7 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&sort_by=vote_average.desc')
r7.json()
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 0,
#    'id': 755459,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Big M',
#    'release_date': '2020-10-20',
#    'original_language': 'ab',
#    'original_title': 'Big M',
#    'genre_ids': [80],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Big M is a giant who is cooking pasta in his basement. A robber breaks into his house and he is forced to kill him.',
#    'poster_path': '/bhPyjrvlgzTWRQ3yN8m6fgoSMjc.jpg'},
#   {'popularity': 0,
#    'id': 755421,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Der Ring des Nibelungen: Das Rheingold',
#    'release_date': '2016-07-26',
#    'original_language': 'de',
#    'original_title': 'Der Ring des Nibelungen: Das Rheingold',
#    'genre_ids': [10402, 18, 14],
#    'backdrop_path': '/tuFZfJfjqTcVjvvW2Ux9NTg9QdE.jpg',
#    'adult': False,
# ...

# %%
r7.json().keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
len(r7.json()['results'])
# Out:
# 20

# %%
highest_vote_average = r7.json()

# %%
highest_vote_average_films = highest_vote_average['results']

# %%
highest_vote_average_films
# Out:
# [{'popularity': 0,
#   'id': 755459,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Big M',
#   'release_date': '2020-10-20',
#   'original_language': 'ab',
#   'original_title': 'Big M',
#   'genre_ids': [80],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Big M is a giant who is cooking pasta in his basement. A robber breaks into his house and he is forced to kill him.',
#   'poster_path': '/bhPyjrvlgzTWRQ3yN8m6fgoSMjc.jpg'},
#  {'popularity': 0,
#   'id': 755421,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Der Ring des Nibelungen: Das Rheingold',
#   'release_date': '2016-07-26',
#   'original_language': 'de',
#   'original_title': 'Der Ring des Nibelungen: Das Rheingold',
#   'genre_ids': [10402, 18, 14],
#   'backdrop_path': '/tuFZfJfjqTcVjvvW2Ux9NTg9QdE.jpg',
#   'adult': False,
# ...

# %%
columns = ['film', 'highest_vote']

# %%
highest_vote_df = pd.DataFrame(columns=columns) #creating DF with about column name

# %%
#add information to DF with API call(url)
for film in highest_vote_df:
    highest_vote = response.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&sort_by=revenue.desc')
    highest_vote = highest_vote.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-8af395d5fa50> in <module>()
#       2 for film in highest_vote_df:
#       3     highest_vote = response.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&sort_by=revenue.desc')
# ----> 4     highest_vote = highest_vote.json()
#       5
#       6
#
# AttributeError: 'NoneType' object has no attribute 'json'

# %%
highest_vote = highest_vote.json()
    highest_vote_df.loc[len(df)]=[film['title'], highest_vote['restlts']]
highest_vote_df.head()
# Out:
#   File "<ipython-input-42-1b62ce256b7e>", line 2
#     highest_vote_df.loc[len(df)]=[film['title'], highest_vote['restlts']]
#     ^
# IndentationError: unexpected indent

# %%
newlist=[]
n=0
while n<50:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?&sort_by=populatity.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist.extend(results)

# %%
len(newlist)
# Out:
# 988

# %%
newlist
# Out:
# [{'popularity': 0.608,
#   'id': 684866,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Le Dernier Chasseur de sorcières',
#   'release_date': '2015-10-28',
#   'original_language': 'fr',
#   'original_title': 'Le Dernier Chasseur de sorcières',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'poster_path': None},
#  {'popularity': 1.4,
#   'id': 753537,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Trading Paint',
#   'release_date': '2019-02-22',
#   'original_language': 'en',
#   'original_title': 'Trading Paint',
#   'genre_ids': [28, 18, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Veteran race car driver Sam Munroe and his son, a fellow driver from a small town overcome family and professional conflicts, balancing competition, ego, resentment and a racing nemesis to come out stronger on the other side.',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-62-f7fd9940f132> in <module>()
#       2 for item in newlist:
#       3     if item['id'] != 684866:
# ----> 4         tmp = tmdb.Movies(item['id']).info()
#       5         movie_dict2[tmp['id']] = tmp['revenue']
#       6 print(movie_dict2)
#
# /Users/andrewbanner/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tmdbsimple/movies.py in info(self, **kwargs)
#      70         path = self._get_id_path('info')
#      71
# ---> 72         response = self._GET(path, kwargs)
#      73         self._set_attrs_to_values(response)
#      74         return response
#
# /Users/andrewbanner/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tmdbsimple/base.py in _GET(self, path, params)
#      91
#      92     def _GET(self, path, params=None):
# ---> 93         return self._request('GET', path, params=params)
# ...
