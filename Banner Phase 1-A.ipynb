# %%
import pandas as pd
import json
import requests
import time
import numpy as np

# %%
import tmdbsimple as tmdb

# %%
tmdb.API_KEY = 'c2d178abd2b6b87a1c24e21c38bd5e24'

# %%
api_key = 'c2d178abd2b6b87a1c24e21c38bd5e24'

# %%
newlist=[]
n=0
while n<500:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?&sort_by=populatity.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist.extend(results)

# %%
newlist
# Out:
# [{'popularity': 0.608,
#   'id': 684866,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Le Dernier Chasseur de sorcières',
#   'release_date': '2015-10-28',
#   'original_language': 'fr',
#   'original_title': 'Le Dernier Chasseur de sorcières',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'poster_path': None},
#  {'popularity': 1.4,
#   'id': 753537,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'Trading Paint',
#   'release_date': '2019-02-22',
#   'original_language': 'en',
#   'original_title': 'Trading Paint',
#   'genre_ids': [28, 18, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Veteran race car driver Sam Munroe and his son, a fellow driver from a small town overcome family and professional conflicts, balancing competition, ego, resentment and a racing nemesis to come out stronger on the other side.',
# ...

# %%
len(newlist)
# Out:
# 9996

# %%
df1 = pd.DataFrame(newlist)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9996 entries, 0 to 9995
# Data columns (total 14 columns):
# popularity           9996 non-null float64
# id                   9996 non-null int64
# video                9996 non-null bool
# vote_count           9996 non-null int64
# vote_average         9996 non-null float64
# title                9996 non-null object
# release_date         9907 non-null object
# original_language    9996 non-null object
# original_title       9996 non-null object
# genre_ids            9996 non-null object
# backdrop_path        6660 non-null object
# adult                9996 non-null bool
# overview             9996 non-null object
# poster_path          8844 non-null object
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 956.8+ KB

# %%
df1
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 0          0.608  684866  False           0           0.0
# 1          1.400  753537  False           0           0.0
# 2          0.000  730707  False           0           0.0
# 3          0.600  615087  False           1           8.0
# 4          1.400  748506  False           0           0.0
# ...          ...     ...    ...         ...           ...
# 9991       1.497  174108  False           4           7.5
# 9992       0.663  174111  False           1           5.0
# 9993       0.600  174113  False           0           0.0
# 9994       1.400  174115  False           3           6.7
# 9995       1.203  174116  False           1           8.0
#
#                                                title release_date  \
# 0                   Le Dernier Chasseur de sorcières   2015-10-28
# 1                                      Trading Paint   2019-02-22
# 2                  Batman: The Batmobile Documentary   2020-05-12
# ...

# %%
df1.sort_values(by='popularity', ascending=False)
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 6991     167.375   11838  False         412           6.6
# 1333     115.507  726682  False           9           7.2
# 120      115.507  726682  False           9           7.2
# 1121      85.459   10439  False        1634           6.9
# 5577      83.946   14836  False        4390           7.7
# ...          ...     ...    ...         ...           ...
# 59         0.000  697013  False           0           0.0
# 57         0.000  703182  False           0           0.0
# 81         0.000  748868  False           0           0.0
# 16         0.000  650027  False           0           0.0
# 106        0.000  752923  False           0           0.0
#
#                                             title release_date  \
# 6991                            Ju-on: The Grudge   2002-10-18
# 1333  Miraculous World : New York – United HeroeZ   2020-09-25
# 120   Miraculous World : New York – United HeroeZ   2020-09-25
# ...

# %%
example = tmdb.Movies(603).info()
example
# Out:
# {'adult': False,
#  'backdrop_path': '/fNG7i7RqMErkcqhohV2a6cV1Ehy.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/lh4aGpd3U9rm9B8Oqr6CUgQLtZL.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 51.001,
#  'poster_path': '/dXNAPwY7VrqMAo51EKhhCJfaGb5.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
# ...

# %%
example = tmdb.Movies(603).info()
example['revenue']
# Out:
# 463517383

# %%
newlist1=[]
n=0
while n<500:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?&sort_by=revenue.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist1.extend(results)

# %%
newlist1
# Out:
# [{'popularity': 1.987,
#   'id': 751181,
#   'video': False,
#   'vote_count': 0,
#   'vote_average': 0,
#   'title': 'El Khetta El Aayma',
#   'release_date': '2020-10-06',
#   'original_language': 'ar',
#   'original_title': 'الخطة العايمة',
#   'genre_ids': [35],
#   'backdrop_path': '/45gi04xjOxBu8s13aiqrXMrL4xw.jpg',
#   'adult': False,
#   'overview': 'As a man enlists the help of two people in order to steal important documents from a safe in a bank, they train two clueless thieves to do the job.',
#   'poster_path': '/bQGF1J3A0riXwdwrCQBVQB5zYvY.jpg'},
#  {'popularity': 1.381,
#   'vote_count': 1,
#   'video': False,
#   'poster_path': None,
#   'id': 755191,
#   'adult': False,
#   'backdrop_path': None,
#   'original_language': 'ru',
#   'original_title': 'Rossiya!',
#   'genre_ids': [35, 18, 10402],
#   'title': 'Russia!',
#   'vote_average': 10,
# ...

# %%
df2 = pd.DataFrame(newlist1)

# %%
df2
# Out:
#      popularity      id  video  vote_count  vote_average  \
# 0         1.987  751181  False           0           0.0
# 1         1.381  755191  False           1          10.0
# 2       217.844  299534  False       15346           8.3
# 3        81.649   19995  False       22183           7.5
# 4        72.755     597  False       17874           7.9
# ..          ...     ...    ...         ...           ...
# 995      25.778    6068  False         880           5.9
# 996      25.750     665  False        1596           7.8
# 997      31.775     214  False        2851           6.4
# 998      14.394      82  False        1098           5.9
# 999       9.530   12193  False         711           5.7
#
#                      title release_date original_language  \
# 0       El Khetta El Aayma   2020-10-06                ar
# 1                  Russia!   1968-04-17                ru
# 2        Avengers: Endgame   2019-04-24                en
# ...

# %%
df2.sort_values(by='release_date', ascending=False)
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 1614       2.333  684358  False           0           0.0
# 2046      14.038  590706  False           0           0.0
# 4215      14.535  748992  False           0           0.0
# 0          1.987  751181  False           0           0.0
# 3618      12.637  604822  False           3           6.7
# ...          ...     ...    ...         ...           ...
# 1033       0.600    2794  False           0           0.0
# 2738       0.600   44976  False           0           0.0
# 3621       0.600   74404  False           0           0.0
# 3931       0.654  132895  False           0           0.0
# 5730       0.600  138350  False           0           0.0
#
#                                                   title release_date  \
# 1614                                         Inevitable   2023-11-03
# 2046                                          Jiu Jitsu   2020-11-20
# ...

# %%
df2.sort_values(by='popularity', ascending=False)
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 2430    1168.889  337401  False        2524           7.3
# 3497     882.810  592350  False         435           8.6
# 3167     733.389  581392  False         622           7.1
# 794      463.702  495764  False        6055           7.2
# 33       434.909  475557  False       15180           8.2
# ...          ...     ...    ...         ...           ...
# 8626       0.600  751262  False           0           0.0
# 5000       0.600  375936  False           0           0.0
# 8523       0.000  755452  False           0           0.0
# 589        0.000  752923  False           0           0.0
# 7755       0.000  755599  False           0           0.0
#
#                                                   title release_date  \
# 2430                                              Mulan   2020-09-04
# 3497                    My Hero Academia: Heroes Rising   2019-12-20
# ...

# %%
df2.sort_values(by='release_date', ascending=False)
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 1614       2.333  684358  False           0           0.0
# 2046      14.038  590706  False           0           0.0
# 4215      14.535  748992  False           0           0.0
# 0          1.987  751181  False           0           0.0
# 3618      12.637  604822  False           3           6.7
# ...          ...     ...    ...         ...           ...
# 1033       0.600    2794  False           0           0.0
# 2738       0.600   44976  False           0           0.0
# 3621       0.600   74404  False           0           0.0
# 3931       0.654  132895  False           0           0.0
# 5730       0.600  138350  False           0           0.0
#
#                                                   title release_date  \
# 1614                                         Inevitable   2023-11-03
# 2046                                          Jiu Jitsu   2020-11-20
# ...

# %%
df2['id'].value_counts()
# Out:
# 2047      1
# 141914    1
# 11679     1
# 288158    1
# 425373    1
#          ..
# 25209     1
# 10872     1
# 316023    1
# 629       1
# 266331    1
# Name: id, Length: 10000, dtype: int64

# %%
newlist3=[]
n=0
while n<100:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?primary_release_year=2010&sort_by=revenue.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist3.extend(results)

# %%
newlist3
# Out:
# [{'popularity': 49.356,
#   'id': 10193,
#   'video': False,
#   'vote_count': 10726,
#   'vote_average': 7.8,
#   'title': 'Toy Story 3',
#   'release_date': '2010-06-16',
#   'original_language': 'en',
#   'original_title': 'Toy Story 3',
#   'genre_ids': [16, 10751, 35],
#   'backdrop_path': '/wE5JGzujfvDPMIfFjJyrhXFjZLc.jpg',
#   'adult': False,
#   'overview': "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   'poster_path': '/4cpGytCB0eqvRks4FAlJoUJiFPG.jpg'},
#  {'popularity': 31.986,
#   'vote_count': 10632,
#   'video': False,
#   'poster_path': '/o0kre9wRCZz3jjSjaru7QU0UtFz.jpg',
#   'id': 12155,
#   'adult': False,
#   'backdrop_path': '/20pkC7yJdCV4J1IMKfsCT9QU7zV.jpg',
#   'original_language': 'en',
#   'original_title': 'Alice in Wonderland',
# ...

# %%
df3 = pd.DataFrame(newlist3)

# %%
df3
# Out:
#       popularity      id  video  vote_count  vote_average  \
# 0         49.356   10193  False       10726           7.8
# 1         31.986   12155  False       10632           6.6
# 2         82.700   12444  False       13497           7.8
# 3         56.345   27205  False       27379           8.3
# 4         55.483   10192  False        4957           6.2
# ...          ...     ...    ...         ...           ...
# 1995       0.656  589136  False           0           0.0
# 1996       0.600  588873  False           0           0.0
# 1997       0.600  588392  False           1           5.0
# 1998       0.653  588344  False           2           3.5
# 1999       0.879  588320  False           1           7.0
#
#                                              title release_date  \
# 0                                      Toy Story 3   2010-06-16
# 1                              Alice in Wonderland   2010-03-03
# 2     Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# ...

# %%
movie_dict = {}

for item in newlist3:
    if item['id'] != 655869:
        tmp = tmdb.Movies(item['id']).info()
        movie_dict[tmp['id']] = tmp['revenue']
    
print(movie_dict)
# Out:
# {10193: 1066969703, 12155: 1025467110, 12444: 954305868, 27205: 825532764, 10192: 752600867, 24021: 698491347, 10138: 623933331, 38757: 592461732, 20352: 543513985, 10191: 494878759, 18823: 493214993, 10140: 415686217, 45269: 414211549, 20526: 400062763, 38575: 357852395, 43956: 347988775, 9543: 335154643, 44214: 329398046, 38055: 321885765, 10196: 318502923, 20662: 310669540, 39451: 310650585, 35791: 300228084, 11324: 294804195, 27576: 293329073, 37786: 288347692, 37710: 278731369, 27578: 274470394, 38365: 271430189, 37834: 261930431, 44264: 252276927, 38745: 237382724, 32657: 226497209, 37799: 224920315, 32856: 216485654, 27022: 215283742, 41733: 211780824, 38167: 204594016, 41515: 201584141, 41436: 177512032, 34544: 177238796, 27581: 170432927, 44048: 167805466, 41233: 159291809, 20504: 157107755, 23168: 154026136, 35056: 152263880, 51739: 145570827, 41216: 140073390, 41439: 136150434, 27573: 136000000, 33909: 134748021, 34851: 127233108, 35019: 123276807, 16290: 117224271, 23437:
# ...

# %%
newlist4=[]
n=0
while n<5:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?primary_release_year=2010&sort_by=revenue.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist4.extend(results)

# %%
newlist4
# Out:
# [{'popularity': 49.356,
#   'id': 10193,
#   'video': False,
#   'vote_count': 10726,
#   'vote_average': 7.8,
#   'title': 'Toy Story 3',
#   'release_date': '2010-06-16',
#   'original_language': 'en',
#   'original_title': 'Toy Story 3',
#   'genre_ids': [16, 10751, 35],
#   'backdrop_path': '/wE5JGzujfvDPMIfFjJyrhXFjZLc.jpg',
#   'adult': False,
#   'overview': "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   'poster_path': '/4cpGytCB0eqvRks4FAlJoUJiFPG.jpg'},
#  {'popularity': 31.986,
#   'vote_count': 10632,
#   'video': False,
#   'poster_path': '/o0kre9wRCZz3jjSjaru7QU0UtFz.jpg',
#   'id': 12155,
#   'adult': False,
#   'backdrop_path': '/20pkC7yJdCV4J1IMKfsCT9QU7zV.jpg',
#   'original_language': 'en',
#   'original_title': 'Alice in Wonderland',
# ...

# %%
df4 = pd.DataFrame(newlist4)

# %%
df4
# Out:
#     popularity     id  video  vote_count  vote_average  \
# 0       49.356  10193  False       10726           7.8
# 1       31.986  12155  False       10632           6.6
# 2       82.700  12444  False       13497           7.8
# 3       56.345  27205  False       27379           8.3
# 4       55.483  10192  False        4957           6.2
# ..         ...    ...    ...         ...           ...
# 95       9.601  35688  False          77           6.2
# 96      18.057  38357  False         988           6.3
# 97      18.862  23169  False        2728           7.1
# 98      17.513  23742  False        1028           5.5
# 99      21.290  29427  False        1291           6.2
#
#                                            title release_date  \
# 0                                    Toy Story 3   2010-06-16
# 1                            Alice in Wonderland   2010-03-03
# 2   Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# ...

# %%
movie_dict2 = {}

for item in newlist4:
        tmp = tmdb.Movies(item['id']).info()
        movie_dict2[tmp['id']] = tmp['revenue']
    
print(movie_dict2)
# Out:
# {10193: 1066969703, 12155: 1025467110, 12444: 954305868, 27205: 825532764, 10192: 752600867, 24021: 698491347, 10138: 623933331, 38757: 592461732, 20352: 543513985, 10191: 494878759, 18823: 493214993, 10140: 415686217, 45269: 414211549, 20526: 400062763, 38575: 357852395, 43956: 347988775, 9543: 335154643, 44214: 329398046, 38055: 321885765, 10196: 318502923, 20662: 310669540, 39451: 310650585, 35791: 300228084, 11324: 294804195, 27576: 293329073, 37786: 288347692, 37710: 278731369, 27578: 274470394, 38365: 271430189, 37834: 261930431, 44264: 252276927, 38745: 237382724, 32657: 226497209, 37799: 224920315, 32856: 216485654, 27022: 215283742, 41733: 211780824, 38167: 204594016, 41515: 201584141, 41436: 177512032, 34544: 177238796, 27581: 170432927, 44048: 167805466, 41233: 159291809, 20504: 157107755, 23168: 154026136, 35056: 152263880, 51739: 145570827, 41216: 140073390, 41439: 136150434, 27573: 136000000, 33909: 134748021, 34851: 127233108, 35019: 123276807, 16290: 117224271, 23437:
# ...

# %%
df_revenue = pd.DataFrame.from_dict(movie_dict2, orient="index").reset_index()
df_revenue.columns = ['id', 'revenue']

# %%
df_revenue
# Out:
#        id     revenue
# 0   10193  1066969703
# 1   12155  1025467110
# 2   12444   954305868
# 3   27205   825532764
# 4   10192   752600867
# ..    ...         ...
# 95  35688    60072596
# 96  38357    58785180
# 97  23169    56032889
# 98  23742    55583804
# 99  29427    54956140
#
# [100 rows x 2 columns]

# %%
df4_revenue = df4.join(df_revenue.set_index('id'), on='id')

# %%
df4_revenue
# Out:
#     popularity     id  vote_count  vote_average  \
# 0       49.356  10193       10726           7.8
# 1       31.986  12155       10632           6.6
# 2       82.700  12444       13497           7.8
# 3       56.345  27205       27379           8.3
# 4       55.483  10192        4957           6.2
# ..         ...    ...         ...           ...
# 95       9.601  35688          77           6.2
# 96      18.057  38357         988           6.3
# 97      18.862  23169        2728           7.1
# 98      17.513  23742        1028           5.5
# 99      21.290  29427        1291           6.2
#
#                                            title release_date  \
# 0                                    Toy Story 3   2010-06-16
# 1                            Alice in Wonderland   2010-03-03
# 2   Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# 3                                      Inception   2010-07-15
# 4                            Shrek Forever After   2010-05-16
# ...

# %%
df4_revenue
# Out:
#     popularity     id  vote_count  vote_average  \
# 0       49.356  10193       10726           7.8
# 1       31.986  12155       10632           6.6
# 2       82.700  12444       13497           7.8
# 3       56.345  27205       27379           8.3
# 4       55.483  10192        4957           6.2
# ..         ...    ...         ...           ...
# 95       9.601  35688          77           6.2
# 96      18.057  38357         988           6.3
# 97      18.862  23169        2728           7.1
# 98      17.513  23742        1028           5.5
# 99      21.290  29427        1291           6.2
#
#                                            title release_date  \
# 0                                    Toy Story 3   2010-06-16
# 1                            Alice in Wonderland   2010-03-03
# 2   Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# 3                                      Inception   2010-07-15
# 4                            Shrek Forever After   2010-05-16
# ...

# %%
df4_revenue_2010 = df4_revenue

# %%
df4_revenue_2010
# Out:
#     popularity     id  vote_count  vote_average  \
# 0       49.356  10193       10726           7.8
# 1       31.986  12155       10632           6.6
# 2       82.700  12444       13497           7.8
# 3       56.345  27205       27379           8.3
# 4       55.483  10192        4957           6.2
# ..         ...    ...         ...           ...
# 95       9.601  35688          77           6.2
# 96      18.057  38357         988           6.3
# 97      18.862  23169        2728           7.1
# 98      17.513  23742        1028           5.5
# 99      21.290  29427        1291           6.2
#
#                                            title release_date  \
# 0                                    Toy Story 3   2010-06-16
# 1                            Alice in Wonderland   2010-03-03
# 2   Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# 3                                      Inception   2010-07-15
# 4                            Shrek Forever After   2010-05-16
# ...

# %%
df4_revenue_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
# popularity        100 non-null float64
# id                100 non-null int64
# vote_count        100 non-null int64
# vote_average      100 non-null float64
# title             100 non-null object
# release_date      100 non-null object
# original_title    100 non-null object
# genre_ids         100 non-null object
# overview          100 non-null object
# revenue           100 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.9+ KB

# %%
newlist5=[]
n=0
while n<5:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?primary_release_year=2011&sort_by=revenue.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist5.extend(results)

# %%
newlist5
# Out:
# [{'popularity': 81.8,
#   'vote_count': 14512,
#   'video': False,
#   'poster_path': '/da22ZBmrDOXOCDRvr8Gic8ldhv4.jpg',
#   'id': 12445,
#   'adult': False,
#   'backdrop_path': '/n5A7brJCjejceZmHyujwUTVgQNC.jpg',
#   'original_language': 'en',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'genre_ids': [12, 14],
#   'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'vote_average': 8.1,
#   'overview': "Harry, Ron and Hermione continue their quest to vanquish the evil Voldemort once and for all. Just as things begin to look hopeless for the young wizards, Harry discovers a trio of magical objects that endow him with powers to rival Voldemort's formidable skills.",
#   'release_date': '2011-07-07'},
#  {'popularity': 7.609,
#   'vote_count': 5952,
#   'video': False,
#   'poster_path': '/wzF3o2eulc5gmOIaNCViqO3nLzK.jpg',
#   'id': 38356,
#   'adult': False,
#   'backdrop_path': '/af2duhAt9evRkxzkhxjgQ1naOM6.jpg',
#   'original_language': 'en',
# ...

# %%
df5 = pd.DataFrame(newlist5)

# %%
movie_dict3 = {}

for item in newlist5:
        tmp = tmdb.Movies(item['id']).info()
        movie_dict3[tmp['id']] = tmp['revenue']
    
print(movie_dict3)
# Out:
# {12445: 1341511219, 38356: 1123794079, 1865: 1045713802, 50619: 712171856, 56292: 694713380, 49444: 631910531, 51497: 626137675, 41513: 563749323, 49013: 559852396, 417859: 554987477, 46195: 484635760, 61791: 482860185, 10195: 449326618, 77338: 426588510, 17578: 371940071, 1771: 370569774, 49538: 353624124, 55301: 342695435, 58574: 334615000, 39254: 299268508, 55721: 288383523, 37686: 260095986, 45243: 254455986, 44896: 245724603, 65754: 232617430, 40805: 227817248, 37958: 226904017, 44912: 219851172, 50014: 216639112, 52449: 216197492, 50546: 214945591, 44943: 211819354, 51540: 209838559, 72571: 205703818, 45772: 189712432, 58224: 187361754, 44826: 185770160, 50359: 183953723, 57212: 177584879, 65057: 177243185, 49849: 174822325, 49530: 173930596, 38317: 169852759, 64328: 165184237, 51876: 161849455, 58233: 160078586, 61202: 160000000, 55779: 157887643, 59108: 152930623, 59436: 151119219, 65759: 150406466, 46529: 149878437, 71880: 149673788, 50544: 149542245, 41630: 149228077, 45612
# ...

# %%
df_revenue1 = pd.DataFrame.from_dict(movie_dict3, orient="index").reset_index()
df_revenue1.columns = ['id', 'revenue']

df5_revenue = df5.join(df_revenue1.set_index('id'), on='id')

# %%
df_revenue1
# Out:
#        id     revenue
# 0   12445  1341511219
# 1   38356  1123794079
# 2    1865  1045713802
# 3   50619   712171856
# 4   56292   694713380
# ..    ...         ...
# 95  49022    65090821
# 96  71469    64626786
# 97  50456    63782078
# 98  68817    63543328
# 99  37430    63523283
#
# [100 rows x 2 columns]

# %%
df5_revenue
# Out:
#     popularity  vote_count     id  \
# 16       1.222        9660  49538
# 70       4.161          30  86718
# 6        4.507        5530  51497
# 46       7.502         203  61202
# 1        7.609        5952  38356
# ..         ...         ...    ...
# 2       47.032       10311   1865
# 12      47.267       15485  10195
# 41      58.395        7966  49530
# 3       63.060        6463  50619
# 0       81.800       14512  12445
#
#                                   original_title        genre_ids  \
# 16                            X-Men: First Class    [28, 878, 12]
# 70                                   7 ஆம் அறிவு    [28, 878, 53]
# 6                                      Fast Five     [28, 80, 53]
# 46                     ज़िन्दगी ना मिलेगी दोबारा  [35, 18, 10749]
# 1                 Transformers: Dark of the Moon    [28, 12, 878]
# ..                                           ...              ...
# 2    Pirates of the Caribbean: On Stranger Tides     [28, 12, 14]
# ...

# %%
df5_revenue.drop(['video', 'poster_path', 'adult', 'backdrop_path', 'original_language'], axis=1, inplace=True)

# %%
df5_revenue.sort_values(by=['vote_average'], inplace=True, ascending=False)

# %%
df5_revenue
# Out:
#     popularity  vote_count     id  \
# 13      31.291       12373  77338
# 28      20.245        5121  50014
# 0       81.800       14512  12445
# 46       7.502         203  61202
# 89      19.814        8618  64690
# ..         ...         ...    ...
# 71      15.575         289  54518
# 96      17.335         895  71469
# 61      32.120        2536  71676
# 82      19.882         658  56288
# 52      19.140        1439  71880
#
#                                   original_title           genre_ids  \
# 13                                  Intouchables            [35, 18]
# 28                                      The Help                [18]
# 0   Harry Potter and the Deathly Hallows: Part 2            [12, 14]
# 46                     ज़िन्दगी ना मिलेगी दोबारा     [35, 18, 10749]
# 89                                         Drive        [18, 53, 80]
# ..                                           ...                 ...
# ...

# %%
example = tmdb.Movies(77338).info()
example
# Out:
# {'adult': False,
#  'backdrop_path': '/bGksau9GGu0uJ8DJQ8DYc9JW5LM.jpg',
#  'belongs_to_collection': None,
#  'budget': 13000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}],
#  'homepage': '',
#  'id': 77338,
#  'imdb_id': 'tt1675434',
#  'original_language': 'fr',
#  'original_title': 'Intouchables',
#  'overview': 'A true story of two men who should never have met – a quadriplegic aristocrat who was injured in a paragliding accident and a young man from the projects.',
#  'popularity': 30.244,
#  'poster_path': '/w7WxNbb0mcWpwDMd3pJA7LQRfnt.jpg',
#  'production_companies': [{'id': 9,
#    'logo_path': '/nda3dTUYdDrJ6rZqBpYvY865aDv.png',
#    'name': 'Gaumont',
#    'origin_country': 'FR'},
#   {'id': 6301, 'logo_path': None, 'name': 'CinéCinéma', 'origin_country': ''},
#   {'id': 7038,
#    'logo_path': '/9YDo78sKAy6xxqBwVBT2Vi9FSZl.png',
#    'name': 'Quad Productions',
#    'origin_country': 'FR'},
# ...

# %%
movie_dict3 = {}

for item in newlist5:
        tmp = tmdb.Movies(item['id']).info()
        movie_dict3[tmp['id']] = tmp['budget']
    
print(movie_dict3)
# Out:
# {12445: 125000000, 38356: 195000000, 1865: 380000000, 50619: 110000000, 56292: 145000000, 49444: 150000000, 51497: 125000000, 41513: 110000000, 49013: 200000000, 417859: 130000000, 46195: 90000000, 61791: 93000000, 10195: 150000000, 77338: 13000000, 17578: 130000000, 1771: 140000000, 49538: 160000000, 55301: 75000000, 58574: 125000000, 39254: 110000000, 55721: 32500000, 37686: 50000000, 45243: 80000000, 44896: 135000000, 65754: 90000000, 40805: 120000000, 37958: 75000000, 44912: 200000000, 50014: 25000000, 52449: 20000000, 50546: 80000000, 44943: 70000000, 51540: 35000000, 72571: 5000000, 45772: 36000000, 58224: 55000000, 44826: 170000000, 50359: 63000000, 57212: 66000000, 65057: 20000000, 49849: 163000000, 49530: 40000000, 38317: 80000000, 64328: 45000000, 51876: 27000000, 58233: 45000000, 61202: 7700000, 55779: 47000000, 59108: 75000000, 59436: 30000000, 65759: 130000000, 46529: 50000000, 71880: 79000000, 50544: 35000000, 41630: 25000000, 45612: 32000000, 50646: 50000000, 62838: 56
# ...

# %%
df_budget = pd.DataFrame.from_dict(movie_dict3, orient="index").reset_index()
df_budget.columns = ['id', 'budget']

# %%
df6_revenue_budget = df5.join(df_budget.set_index('id'), on='id')

# %%
df6_revenue_budget
# Out:
#     popularity  vote_count  video                       poster_path     id  \
# 0       81.800       14512  False  /da22ZBmrDOXOCDRvr8Gic8ldhv4.jpg  12445
# 1        7.609        5952  False  /wzF3o2eulc5gmOIaNCViqO3nLzK.jpg  38356
# 2       47.032       10311  False  /9zxsSzXx2UO3yNoS4j97vs4uOhc.jpg   1865
# 3       63.060        6463  False  /dSSzv6JrlwS48pBeTNSswLJXOYF.jpg  50619
# 4       45.332        7234  False  /7GCKNRbzcA4rJXAKoE8KS9IDnZP.jpg  56292
# ..         ...         ...    ...                               ...    ...
# 95      13.908         719  False  /9oieyNEluxHmtHS0TepM5EUBiDU.jpg  49022
# 96      17.335         895  False  /5Ao4qAFbjP7fcFOOdMNvQEnl0Yr.jpg  71469
# 97      16.169        2347  False  /gRvxRMtejJa9jjfDDUibUIfIJbP.jpg  50456
# 98      14.425        1173  False  /rzTuPCtIBuL4LPJBbNA5RnXDzPZ.jpg  68817
# 99      32.104        1280  False  /vR6PzXsOfewD1kei8gMbepvwWC6.jpg  37430
#
#     adult                     backdrop_path original_language  \
# ...

# %%
newlist5=[]
n=0
while n<5:
    n+=1
    url='http://api.themoviedb.org/3/discover/movie?primary_release_year=2011&sort_by=revenue.desc&offset=20&page={}&api_key='.format(n)
    req=requests.get(url+api_key).json()
    results=req['results']
    newlist5.extend(results)
